# %%
import pandas as pd

# %%
# df = pd.read_csv('penalty_data2_processed_dpr.csv')
# df[df['Plant Name'].duplicated()]
# df.info()

# %%
df = pd.read_csv('penalty_data2_processed.csv',index_col=0)

df.dropna(how='all',inplace=True)

df['AVC (MW)'] = df.loc[:,'AVC (MW)'].str.replace(',','').astype(float)

df = df.reset_index()

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 76 entries, 0 to 75
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Plant Name          76 non-null     object
#  1   Forecasting Agency  76 non-null     object
#  2   Apr                 71 non-null     float64
#  3   May                 72 non-null     float64
#  4   Jun                 72 non-null     float64
#  5   Jul                 72 non-null     float64
#  6   Aug                 75 non-null     float64
#  7   Sep                 76 non-null     float64
#  8   Oct                 75 non-null     float64
#  9   Nov                 75 non-null     float64
#  10  YTD                 75 non-null     float64
#  11  Transmission        76 non-null     object
#  12  Region              76 non-null     object
#  13  AVC (MW)            76 non-null     float64
#  14  Plant Type          76 non-null     object
# ...

# %%
df['Plant Name'].nunique()
# Out:
# 76

# %%
df.to_csv('penalty_data2_processed_dpr2.csv',index=False)

# %%
df[df['YTD'].isna()]
# Out:
#         Plant Name Forecasting Agency  Apr   May   Jun   Jul   Aug   Sep  Oct  \
# 13  ASERJ2PL_180MW               AGEL  0.6  2.22  4.09  7.33  3.95  3.13  1.8
#
#     Nov  YTD Transmission Region  AVC (MW) Plant Type Access Type
# 13  NaN  NaN          CTU     NR     180.0      Solar         LTA
